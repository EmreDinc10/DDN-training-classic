# %%
# ============================================================================
# CELL 0: Check GPU Availability
# ============================================================================
# IMPORTANT: Enable GPU first!
# Go to: Runtime -> Change runtime type -> Hardware accelerator -> GPU

import torch

print("="*60)
print("GPU CHECK")
print("="*60)
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    print(f"GPU memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
    print("✓ GPU is ready!")
else:
    print("⚠ WARNING: No GPU detected!")
    print("Please enable GPU: Runtime -> Change runtime type -> GPU")
    print("Then restart runtime and run this cell again.")
print("="*60)
# Out:
# Cloning into 'DDN-training-classic'...
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 60 (delta 9), reused 57 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (60/60), 117.53 KiB | 7.35 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/DDN-training-classic
# Collecting git+https://github.com/openai/CLIP.git (from -r requirements.txt (line 9))
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-x8jw98it
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-x8jw98it
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting sddn>=0.0.2 (from -r requirements.txt (line 1))
#   Downloading sddn-0.0.2-py3-none-any.whl.metadata (606 bytes)
# Collecting boxx>=0.10.16 (from -r requirements.txt (line 2))
#   Downloading boxx-0.10.16-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (8.3.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.36.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (5.50.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from boxx>=0.10.16->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: scikit_image in /usr/local/lib/python3.12/dist-packages (from boxx>=0.10.16->-r requirements.txt (line 2)) (0.25.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from boxx>=0.10.16->-r requirements.txt (line 2)) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from boxx>=0.10.16->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from boxx>=0.10.16->-r requirements.txt (line 2)) (2.37.2)
# Collecting snakeviz (from boxx>=0.10.16->-r requirements.txt (line 2))
#   Downloading snakeviz-2.2.2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.12/dist-packages (from boxx>=0.10.16->-r requirements.txt (line 2)) (3.1.10)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from boxx>=0.10.16->-r requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 7)) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 7)) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 7)) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.118.3)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: gradio-client==1.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (3.11.5)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: pydantic<=2.12.3,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.14.8)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.48.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.20.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r requirements.txt (line 8)) (0.38.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.14.0->gradio->-r requirements.txt (line 8)) (15.0.1)
# Collecting ftfy (from clip==1.0->-r requirements.txt (line 9))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from clip==1.0->-r requirements.txt (line 9)) (2025.11.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from clip==1.0->-r requirements.txt (line 9)) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from clip==1.0->-r requirements.txt (line 9)) (0.24.0+cu126)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 8)) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 8)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->boxx>=0.10.16->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->boxx>=0.10.16->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->boxx>=0.10.16->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio->-r requirements.txt (line 8)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<=2.12.3,>=2.0->gradio->-r requirements.txt (line 8)) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (13.9.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->clip==1.0->-r requirements.txt (line 9)) (0.2.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->boxx>=0.10.16->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->boxx>=0.10.16->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->boxx>=0.10.16->-r requirements.txt (line 2)) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->boxx>=0.10.16->-r requirements.txt (line 2)) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->boxx>=0.10.16->-r requirements.txt (line 2)) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->-r requirements.txt (line 7)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->-r requirements.txt (line 7)) (2.5.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit_image->boxx>=0.10.16->-r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit_image->boxx>=0.10.16->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit_image->boxx>=0.10.16->-r requirements.txt (line 2)) (2025.10.16)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit_image->boxx>=0.10.16->-r requirements.txt (line 2)) (0.4)
# Requirement already satisfied: tornado>=2.0 in /usr/local/lib/python3.12/dist-packages (from snakeviz->boxx>=0.10.16->-r requirements.txt (line 2)) (6.5.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (1.14.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0->-r requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->boxx>=0.10.16->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->clip==1.0->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 8)) (0.1.2)
# Downloading sddn-0.0.2-py3-none-any.whl (9.5 kB)
# Downloading boxx-0.10.16-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.7 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
# Downloading snakeviz-2.2.2-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.5/183.5 kB 13.7 MB/s eta 0:00:00
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369490 sha256=057a6d1cf169e11f558936f35f1950c5c3d946fc9d9e6a2e69d41da5e26054b6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9g0bi2h6/wheels/35/3e/df/3d24cbfb3b6a06f17a2bfd7d1138900d4365d9028aa8f6e92f
# Successfully built clip
# Installing collected packages: snakeviz, ftfy, boxx, sddn, clip
# Successfully installed boxx-0.10.16 clip-1.0 ftfy-6.3.1 sddn-0.0.2 snakeviz-2.2.2
# ✓ Setup complete!

# %%
# ============================================================================
# CELL 1: Setup
# ============================================================================
# Make sure GPU is enabled (check previous cell output)

# !git clone https://github.com/EmreDinc10/DDN-training-classic.git
# %cd DDN-training-classic
# !pip install -r requirements.txt

# Verify GPU again after setup
import torch
if not torch.cuda.is_available():
    print("⚠ ERROR: GPU still not available. Please enable GPU in Runtime settings!")
    raise RuntimeError("GPU required for training")

print("✓ Setup complete!")

# %%
# ============================================================================
# CELL 2: Prepare MNIST Dataset
# ============================================================================
import torchvision
from torchvision.datasets import MNIST
import os

# Create datasets directory
os.makedirs("datasets", exist_ok=True)
os.makedirs("datasets/mnist_temp", exist_ok=True)

# Download MNIST and save as images
print("Downloading MNIST dataset...")
mnist_train = MNIST(root="datasets/mnist_temp", train=True, download=True, transform=None)

# Save images to temporary directory
print("Converting MNIST to images...")
for idx in range(len(mnist_train)):
    img, label = mnist_train[idx]
    # Convert to RGB (3 channels)
    img_rgb = img.convert('RGB')
    img_rgb.save(f"datasets/mnist_temp/{idx:05d}_{label}.png")

# Create ZIP file using dataset_tool.py
print("Creating ZIP dataset...")
# !python dataset_tool.py --source=datasets/mnist_temp --dest=datasets/mnist-28x28.zip

# Cleanup
# !rm -rf datasets/mnist_temp
print("✓ MNIST dataset ready at: datasets/mnist-28x28.zip")
# Out:
# Downloading MNIST dataset...
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 133MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 36.2MB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 26.4MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.48MB/s]
# Converting MNIST to images...
# Creating ZIP dataset...
#   0% 0/60000 [00:00<?, ?it/s]
# Error: Image width/height after scale and crop are required to be power-of-two
# ✓ MNIST dataset ready at: datasets/mnist-28x28.zip

# %%
# ============================================================================
# CELL 3: Configure and Run Training
# ============================================================================
import os

# Set configuration for MNIST
os.environ["DATA_PATH"] = "datasets/mnist-28x28.zip"
os.environ["OUTDIR"] = "/content/training-runs/mnist-test"
os.environ["BATCH_SIZE"] = "32"
os.environ["BATCH_GPU"] = "32"
os.environ["TOTAL_KIMG"] = "10"  # 10k images = ~10 minutes

print("Configuration:")
print(f"  Dataset: {os.environ['DATA_PATH']}")
print(f"  Output: {os.environ['OUTDIR']}")
print(f"  Batch size: {os.environ['BATCH_SIZE']}")
print(f"  Training duration: {os.environ['TOTAL_KIMG']}k images (~{int(os.environ['TOTAL_KIMG']) * 0.5:.1f} min)")

# Run training
# !python train_minimal.py
# Out:
# Configuration:
#   Dataset: datasets/mnist-28x28.zip
#   Output: /content/training-runs/mnist-test
#   Batch size: 32
#   Training duration: 10k images (~5.0 min)
# Traceback (most recent call last):
#   File "/content/DDN-training-classic/train_minimal.py", line 13, in <module>
#     dist.init()
#   File "/content/DDN-training-classic/torch_utils/distributed.py", line 28, in init
#     torch.distributed.init_process_group(backend=backend, init_method="env://")
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/c10d_logger.py", line 81, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/c10d_logger.py", line 95, in wrapper
#     func_return = func(*args, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py", line 1769, in init_process_group
#     default_pg, _ = _new_process_group_helper(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/distributed/distributed_c10d.py", line 2027, in _new_process_group_helper
#     backend_class = ProcessGroupNCCL(
#                     ^^^^^^^^^^^^^^^^^
# ValueError: ProcessGroupNCCL is only supported with GPUs, no GPUs found!
